# %% [markdown]
# importation de pandas

# %%
import pandas as pd

# %% [markdown]
# Lire le fichier data.csv

# %%
df = pd.read_csv("DataSource/data.csv")

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df.head(10)
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
# 5   6  03/25/2021      Titos  Braybrooke   tbraybrooke5@umn.edu  Female
# 6   7  03/14/2021        Ava     Kencott     akencott6@phoca.cz  Female
# 7   8  03/08/2021       Codi     Feasley       cfeasley7@ed.gov    Male
# 8   9  03/09/2021     Waylon    Heersema  wheersema8@tumblr.com    Male
# 9  10  03/23/2021  Guglielma      Gookes  ggookes9@amazon.co.uk    Male
#
#         ip_address        country price_paid   tax
# 0    160.119.8.119         Canada      $5.36   NaN
# 1   210.51.172.132         Canada      $8.32   NaN
# ...

# %%
df.tail(10)
# Out:
#        id        date first_name   last_name                       email  \
# 990   991  03/19/2021       Shep    Thorburn  sthorburnri@prnewswire.com
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 992   993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 993   994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender      ip_address        country price_paid   tax
# 990    Male  108.123.252.15         France      $7.02  20.0
# ...

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.columns
# Out:
# Index(['id', 'date', 'first_name', 'last_name', 'email', 'gender',
#        'ip_address', 'country', 'price_paid', 'tax'],
#       dtype='object')

# %%
dfcopy = df.copy()

# %%
dfRename =dfcopy.rename(columns=
                        {'first_name':'nom', 
                         'last_name':'prenom',
                         'gender':'sexe',
                         'country':'pays',
                         'price_paid':'avant_taxe',
                         'tax':'taxe'
                        },
                         inplace=True)

# %%
dfRename

# %%
dfRename

# %%
dfcopy
# Out:
#        id        date       nom      prenom                       email  \
# 0       1  03/28/2021   Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021     Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021       Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021     Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021     Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...       ...         ...                         ...
# 995   996  03/24/2021      Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021       Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021     Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021   Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021  Rochelle    Pringuer       rpringuerrr@house.gov
#
#        sexe       ip_address           pays avant_taxe  taxe
# ...

# %%
dfcopy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   date        1000 non-null   object
#  2   nom         1000 non-null   object
#  3   prenom      1000 non-null   object
#  4   email       1000 non-null   object
#  5   sexe        931 non-null    object
#  6   ip_address  1000 non-null   object
#  7   pays        956 non-null    object
#  8   avant_taxe  1000 non-null   object
#  9   taxe        654 non-null    float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 78.2+ KB

# %% [markdown]
# -------------------------------------------- Les filtres et comment supprimer une colonne-----------------------------------

# %%
dfcopy
# Out:
#        id        date       nom      prenom                       email  \
# 0       1  03/28/2021   Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021     Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021       Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021     Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021     Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...       ...         ...                         ...
# 995   996  03/24/2021      Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021       Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021     Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021   Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021  Rochelle    Pringuer       rpringuerrr@house.gov
#
#        sexe       ip_address           pays avant_taxe  taxe
# ...

# %%
dfcopy["pays"]=="Canada"
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: pays, Length: 1000, dtype: bool

# %%
dfcopy[(dfcopy["pays"]=="Canada") &  (dfcopy["sexe"]=="Male")  & (dfcopy["taxe"].notnull())]
# Out:
#       id        date        nom      prenom  \
# 8      9  03/09/2021     Waylon    Heersema
# 19    20  03/01/2021     Sibeal      Mounch
# 21    22  03/05/2021     Mendie        Ayer
# 22    23  03/03/2021     Muriel      Pexton
# 69    70  03/16/2021       Jose       Oliva
# 82    83  03/20/2021      Ricca      Mantle
# 98    99  03/06/2021    Gerardo      Antley
# 132  133  03/26/2021     Nowell      Nelson
# 157  158  03/19/2021      Clare       Wloch
# 160  161  03/23/2021       Elke      Baroch
# 161  162  03/10/2021   Magdalen     Karpman
# 188  189  03/22/2021     Rutger       Swett
# 222  223  03/26/2021   Lockwood      Sweedy
# 237  238  03/05/2021      Nonie      Barwis
# 252  253  03/05/2021     Trenna  Jaskiewicz
# 257  258  03/11/2021       Dyna    Saberton
# 261  262  03/07/2021    Glennis      Bossel
# 286  287  03/15/2021      Alvie        Thaw
# 302  303  03/20/2021       Audi      Davies
# 338  339  03/14/2021       Burr    Custance
# ...

# %%
dfcopy.isna().sum()
# Out:
# id              0
# date            0
# nom             0
# prenom          0
# email           0
# sexe           69
# ip_address      0
# pays           44
# avant_taxe      0
# taxe          346
# dtype: int64

# %%
dfcopy.query("sexe =='Female' & pays=='Morocco'")
# Out:
#       id        date          nom       prenom                          email  \
# 30    31  03/28/2021        Tommi    Ditchburn          tditchburnu@bbc.co.uk
# 88    89  03/21/2021        Randy        Tiebe       rtiebe2g@livejournal.com
# 158  159  03/07/2021      Ethelin         Gors      egors4e@blogtalkradio.com
# 168  169  03/01/2021       Willis  Sandercroft         wsandercroft4o@loc.gov
# 195  196  03/22/2021    Frederica   Stuchburie        fstuchburie5f@ocn.ne.jp
# 205  206  03/29/2021       Kendal      Huleatt      khuleatt5p@shutterfly.com
# 301  302  03/22/2021        Ollie    Suermeier   osuermeier8d@istockphoto.com
# 316  317  03/28/2021       Duncan      Dymocke         ddymocke8s@archive.org
# 362  363  03/22/2021       Mureil       Bartke   mbartkea2@simplemachines.org
# 375  376  03/14/2021      Abagael     Lafflina          alafflinaaf@prlog.org
# 379  380  03/21/2021     Sheelagh      Gilmore            sgilmoreaj@bing.com
# ...

# %%
dfcopy[dfcopy["pays"].isin(["Canada","France"])]
# Out:
#        id        date       nom      prenom                      email  \
# 0       1  03/28/2021   Marylin      Alders       malders0@shop-pro.jp
# 1       2  03/19/2021     Hinda    Harridge         hharridge1@gnu.org
# 6       7  03/14/2021       Ava     Kencott         akencott6@phoca.cz
# 7       8  03/08/2021      Codi     Feasley           cfeasley7@ed.gov
# 8       9  03/09/2021    Waylon    Heersema      wheersema8@tumblr.com
# ..    ...         ...       ...         ...                        ...
# 992   993  03/04/2021   Maurene  Guilloneau     mguilloneaurk@about.me
# 993   994  03/22/2021     Ossie      Snelle           osnellerl@nhs.uk
# 994   995  03/17/2021  Carolyne    Bruntjen  cbruntjenrm@reference.com
# 995   996  03/24/2021      Duff      Errigo       derrigorn@elpais.com
# 999  1000  03/23/2021  Rochelle    Pringuer      rpringuerrr@house.gov
#
#        sexe      ip_address    pays avant_taxe  taxe
# 0      Male   160.119.8.119  Canada      $5.36   NaN
# ...

# %%
dfcopy["taxe"].isnull().sum()
# Out:
# 346

# %%
dfcopy[dfcopy.eval("sexe == 'Male' &  pays.isnull() ")]
# Out:
#       id        date         nom      prenom                            email  \
# 89    90  03/03/2021     Laverne    Dunbobin        ldunbobin2h@indiegogo.com
# 167  168  03/17/2021     Patrick       Akers           pakers4n@clickbank.net
# 210  211  03/03/2021   Merrielle      Jarret                mjarret5u@epa.gov
# 241  242  03/15/2021         Lee  Dillestone      ldillestone6p@homestead.com
# 264  265  03/21/2021       Brock   Spridgeon        bspridgeon7c@buzzfeed.com
# 288  289  03/27/2021       Homer      Testin                 htestin80@gov.uk
# 331  332  03/28/2021       Sibyl     Crystal             scrystal97@yandex.ru
# 358  359  03/01/2021        Etan      Muller               emuller9y@army.mil
# 443  444  03/14/2021       Clyde     Braundt               cbraundtcb@wsj.com
# 458  459  03/12/2021  Bernardine      Caslin        bcaslincq@ycombinator.com
# 587  588  03/23/2021      Xavier    Sleeford  xsleefordgb@theglobeandmail.com
# ...

# %% [markdown]
#  *********************************  Les lignes : iloc  et loc***************************************************

# %%
dfcopy
# Out:
#        id        date       nom      prenom                       email  \
# 0       1  03/28/2021   Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021     Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021       Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021     Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021     Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...       ...         ...                         ...
# 995   996  03/24/2021      Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021       Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021     Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021   Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021  Rochelle    Pringuer       rpringuerrr@house.gov
#
#        sexe       ip_address           pays avant_taxe  taxe
# ...

# %%
dfcopy.iloc[0,1]
# Out:
# '03/28/2021'

# %%
dfcopy.iloc[0:3]
# Out:
#    id        date      nom      prenom                  email    sexe  \
# 0   1  03/28/2021  Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021    Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021      Erl  Kilminster  ekilminster2@etsy.com    Male
#
#        ip_address           pays avant_taxe  taxe
# 0   160.119.8.119         Canada      $5.36   NaN
# 1  210.51.172.132         Canada      $8.32   NaN
# 2   213.8.101.145  United States      $3.73  20.0

# %%
dfcopy.iloc[0:3,0:3]
# Out:
#    id        date      nom
# 0   1  03/28/2021  Marylin
# 1   2  03/19/2021    Hinda
# 2   3  03/17/2021      Erl

# %%
dfcopy.iloc[0:3,2:5]
# Out:
#        nom      prenom                  email
# 0  Marylin      Alders   malders0@shop-pro.jp
# 1    Hinda    Harridge     hharridge1@gnu.org
# 2      Erl  Kilminster  ekilminster2@etsy.com

# %%
dfcopy
# Out:
#        id        date       nom      prenom                       email  \
# 0       1  03/28/2021   Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021     Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021       Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021     Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021     Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...       ...         ...                         ...
# 995   996  03/24/2021      Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021       Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021     Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021   Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021  Rochelle    Pringuer       rpringuerrr@house.gov
#
#        sexe       ip_address           pays avant_taxe  taxe
# ...

# %%
dfcopy
# Out:
#        id        date       nom      prenom                       email  \
# 0       1  03/28/2021   Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021     Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021       Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021     Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021     Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...       ...         ...                         ...
# 995   996  03/24/2021      Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021       Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021     Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021   Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021  Rochelle    Pringuer       rpringuerrr@house.gov
#
#        sexe       ip_address           pays avant_taxe  taxe
# ...

# %%
dfcopy.set_index("sexe",inplace=True)

# %%
dfcopy
# Out:
#           id        date       nom      prenom                       email  \
# sexe
# Male       1  03/28/2021   Marylin      Alders        malders0@shop-pro.jp
# Female     2  03/19/2021     Hinda    Harridge          hharridge1@gnu.org
# Male       3  03/17/2021       Erl  Kilminster       ekilminster2@etsy.com
# Female     4  03/19/2021     Grata      Brantl            gbrantl3@umn.edu
# Male       5  03/24/2021     Kanya     Beasant         kbeasant4@jigsy.com
# ...      ...         ...       ...         ...                         ...
# Female   996  03/24/2021      Duff      Errigo        derrigorn@elpais.com
# Female   997  03/17/2021       Ame     Rastall       arastallro@toplist.cz
# Male     998  03/13/2021     Betty    Stickels  bstickelsrp@cloudflare.com
# Male     999  03/17/2021   Paquito       Tesoe      ptesoerq@rakuten.co.jp
# NaN     1000  03/23/2021  Rochelle    Pringuer       rpringuerrr@house.gov
#
#              ip_address           pays avant_taxe  taxe
# ...

# %%
dfcopy.loc["Male"]
# Out:
#        id        date      nom      prenom                       email  \
# sexe
# Male    1  03/28/2021  Marylin      Alders        malders0@shop-pro.jp
# Male    3  03/17/2021      Erl  Kilminster       ekilminster2@etsy.com
# Male    5  03/24/2021    Kanya     Beasant         kbeasant4@jigsy.com
# Male    8  03/08/2021     Codi     Feasley            cfeasley7@ed.gov
# Male    9  03/09/2021   Waylon    Heersema       wheersema8@tumblr.com
# ...   ...         ...      ...         ...                         ...
# Male  992  03/07/2021    Elihu       Crush       ecrushrj@berkeley.edu
# Male  993  03/04/2021  Maurene  Guilloneau      mguilloneaurk@about.me
# Male  994  03/22/2021    Ossie      Snelle            osnellerl@nhs.uk
# Male  998  03/13/2021    Betty    Stickels  bstickelsrp@cloudflare.com
# Male  999  03/17/2021  Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#            ip_address           pays avant_taxe  taxe
# sexe
# ...

# %%
dfcopy.loc[dfcopy["pays"]=="Canada"]
# Out:
#           id        date        nom      prenom                      email  \
# sexe
# Male       1  03/28/2021    Marylin      Alders       malders0@shop-pro.jp
# Female     2  03/19/2021      Hinda    Harridge         hharridge1@gnu.org
# Female     7  03/14/2021        Ava     Kencott         akencott6@phoca.cz
# Male       9  03/09/2021     Waylon    Heersema      wheersema8@tumblr.com
# Male      11  03/11/2021       Lief   Woodcraft  lwoodcrafta@sitemeter.com
# ...      ...         ...        ...         ...                        ...
# Male     965  03/16/2021    Marilyn   McKiernan       mmckiernanqs@mapy.cz
# Female   970  03/15/2021       Dody  Jakubovics    djakubovicsqx@ifeng.com
# Female   972  03/09/2021      Devan      Kamena          dkamenaqz@umn.edu
# Male     979  03/18/2021  Bartolemo     Veelers      bveelersr6@smh.com.au
# NaN     1000  03/23/2021   Rochelle    Pringuer      rpringuerrr@house.gov
#
#              ip_address    pays avant_taxe  taxe
# sexe
# ...

# %%
dfcopy
# Out:
#           id        date       nom      prenom                       email  \
# sexe
# Male       1  03/28/2021   Marylin      Alders        malders0@shop-pro.jp
# Female     2  03/19/2021     Hinda    Harridge          hharridge1@gnu.org
# Male       3  03/17/2021       Erl  Kilminster       ekilminster2@etsy.com
# Female     4  03/19/2021     Grata      Brantl            gbrantl3@umn.edu
# Male       5  03/24/2021     Kanya     Beasant         kbeasant4@jigsy.com
# ...      ...         ...       ...         ...                         ...
# Female   996  03/24/2021      Duff      Errigo        derrigorn@elpais.com
# Female   997  03/17/2021       Ame     Rastall       arastallro@toplist.cz
# Male     998  03/13/2021     Betty    Stickels  bstickelsrp@cloudflare.com
# Male     999  03/17/2021   Paquito       Tesoe      ptesoerq@rakuten.co.jp
# NaN     1000  03/23/2021  Rochelle    Pringuer       rpringuerrr@house.gov
#
#              ip_address           pays avant_taxe  taxe
# ...

# %%
dfcopy.drop(["ip_address"], axis=1,inplace=True)

# %%
dfcopy
# Out:
#                 date      prenom           pays avant_taxe  taxe
# nom
# Marylin   03/28/2021      Alders         Canada      $5.36   NaN
# Hinda     03/19/2021    Harridge         Canada      $8.32   NaN
# Erl       03/17/2021  Kilminster  United States      $3.73  20.0
# Grata     03/19/2021      Brantl  United States      $3.70  20.0
# Kanya     03/24/2021     Beasant        Morocco      $9.24  20.0
# ...              ...         ...            ...        ...   ...
# Duff      03/24/2021      Errigo         France      $3.63   NaN
# Ame       03/17/2021     Rastall            NaN      $4.59  20.0
# Betty     03/13/2021    Stickels  United States      $7.54  20.0
# Paquito   03/17/2021       Tesoe  United States      $5.81   NaN
# Rochelle  03/23/2021    Pringuer         Canada      $8.01  20.0
#
# [1000 rows x 5 columns]

# %%
dfcopy.drop(["id","email"], axis=1,inplace=True)

# %%
dfcopy
# Out:
#               date       nom      prenom           pays avant_taxe  taxe
# sexe
# Male    03/28/2021   Marylin      Alders         Canada      $5.36   NaN
# Female  03/19/2021     Hinda    Harridge         Canada      $8.32   NaN
# Male    03/17/2021       Erl  Kilminster  United States      $3.73  20.0
# Female  03/19/2021     Grata      Brantl  United States      $3.70  20.0
# Male    03/24/2021     Kanya     Beasant        Morocco      $9.24  20.0
# ...            ...       ...         ...            ...        ...   ...
# Female  03/24/2021      Duff      Errigo         France      $3.63   NaN
# Female  03/17/2021       Ame     Rastall            NaN      $4.59  20.0
# Male    03/13/2021     Betty    Stickels  United States      $7.54  20.0
# Male    03/17/2021   Paquito       Tesoe  United States      $5.81   NaN
# NaN     03/23/2021  Rochelle    Pringuer         Canada      $8.01  20.0
#
# [1000 rows x 6 columns]

# %%
dfcopy.set_index("nom",inplace=True)

# %%
dfcopy
# Out:
#                 date      prenom           pays avant_taxe  taxe
# nom
# Marylin   03/28/2021      Alders         Canada      $5.36   NaN
# Hinda     03/19/2021    Harridge         Canada      $8.32   NaN
# Erl       03/17/2021  Kilminster  United States      $3.73  20.0
# Grata     03/19/2021      Brantl  United States      $3.70  20.0
# Kanya     03/24/2021     Beasant        Morocco      $9.24  20.0
# ...              ...         ...            ...        ...   ...
# Duff      03/24/2021      Errigo         France      $3.63   NaN
# Ame       03/17/2021     Rastall            NaN      $4.59  20.0
# Betty     03/13/2021    Stickels  United States      $7.54  20.0
# Paquito   03/17/2021       Tesoe  United States      $5.81   NaN
# Rochelle  03/23/2021    Pringuer         Canada      $8.01  20.0
#
# [1000 rows x 5 columns]

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...
